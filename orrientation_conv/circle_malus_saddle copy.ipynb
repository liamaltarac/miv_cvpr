# %%
import sys
sys.path.append('../')

import numpy as np
from scipy import ndimage

from skimage.filters import sobel_h
from skimage.filters import sobel_v
from scipy import stats


import os
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.proj3d import proj_transform
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d


import scienceplots
from tensorflow.python.client import device_lib

#plt.rcParams['figure.figsize'] = [10,10]

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import decode_predictions
from tensorflow.keras.applications import VGG16

from tensorflow.nn import depthwise_conv2d
from tensorflow.math import multiply, reduce_sum, reduce_mean,reduce_euclidean_norm, sin, cos, abs
from tensorflow import stack, concat, expand_dims

import tensorflow_probability as tfp

from utils.utils import *
import cv2


from PIL import Image

from scipy import ndimage, fft

plt.style.use(['science', 'ieee'])
plt.rcParams.update({'figure.dpi': '100'})
# Out:
# 2025-09-17 11:54:38.809697: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-17 11:54:38.949508: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758124479.009960   10703 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758124479.028237   10703 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758124479.141098   10703 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758124479.141117   10703 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758124479.141119   10703 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758124479.141120   10703 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-17 11:54:39.155873: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### Experiment #1 : Symmetric Convolution

# %%
'''img = np.zeros((45, 45))
center_coordinates = (img.shape[0]//2, img.shape[1]//2) 
img = cv2.circle(img, center_coordinates, 20, (255,255,255), -1) 
plt.imshow(img)'''


N = 50
#img =  tf.image.rot90(tf.random.uniform(shape=(50,50,1), minval=0., maxval=1.), k=1) #
#img = tf.image.pad_to_bounding_box(img, 25//2,25//2,N+25, N+25)[...,0]

img =  tf.expand_dims(cv2.imread('input4.png', 0)/255. , axis=-1)
H, W, C = img.shape  # Get image dimensions
offset_height = (H - N) // 2
offset_width = (W - N) // 2
img = tf.image.crop_to_bounding_box(img, offset_height, offset_width, N, N)[...,0]
plt.imshow(img)
img.shape
# Out:
# I0000 00:00:1758124483.436437   10703 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4280 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# TensorShape([50, 50])

# %%
#var = 2/(128*9)

fig,ax = plt.subplots(1)

ax.imshow(img, cmap='gray')

#img = (img-np.mean(img))/np.std(img)
#img = tf.repeat(tf.expand_dims([img], axis=-1) , repeats = 512, axis=-1)  #get_double_slit(shape) , axis=0)
print(img.shape)
plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.savefig("input.png",bbox_inches='tight',   pad_inches = 0)
# Out:
# (50, 50)

# %%
img = np.random.normal(loc=0.0, scale=1.0, size=(500, 500))
print("Original shape:", img.shape)

# Pad with 10 pixels of zeros on all sides
img = np.pad(img, pad_width=((10, 10), (10, 10)), mode='constant', constant_values=0)

fig, ax = plt.subplots()
ax.imshow(img)
x_min, x_max = 30, 60
y_min, y_max = 30, 60

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

plt.show()
# Out:
# Original shape: (500, 500)

# %%
k = 32
w = np.zeros((k,k,1,1))


t1 = np.zeros((k,k))
t2 = np.zeros((k,k))
t3 = np.zeros((k,k))
t4 = np.zeros((k,k))
t5 = np.zeros((k,k))

'''t1[1, 2] = 1.
t2[2, 1] = 1.'''
t1[0,4] = 1.
t2[1, 3] = 1.
t3[2, 2] = 1.
t4[3, 1] = 1.
t5[4, 0] = 1.


w1 = fft.idctn(t1, norm='ortho')
#w1 /= np.sum(np.abs(w1))

w2 = fft.idctn(t2, norm='ortho') #-  fft.idctn(t3, norm='ortho')

w3 =  fft.idctn(t3, norm='ortho') 

w4 =  fft.idctn(t4, norm='ortho') 

w5 =  fft.idctn(t5, norm='ortho') 




#w2 /= np.sum(np.abs(w2))

frames = []
angles = np.linspace(-np.pi, np.pi, 100)

angle0 = np.pi/8


for angle in angles :    
    
    fig, ax = plt.subplots()


    w[:,:,0,0] = w1 * (np.cos(angle)**4 )+ w5*(np.sin(angle)**4) + w3* 6*(np.cos(angle)**2 )* (np.sin(angle)**2)  - \
                 w2 * 4 * (np.cos(angle)**3) * (np.sin(angle))  - w4 * 4 * (np.sin(angle)**3) * (np.cos(angle))




    print(tf.math.reduce_euclidean_norm(w))
    w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))


    im = ax.imshow(w[:,:,0,0], cmap=cm.viridis, animated=True)
    ax.axis("off")

    fig.canvas.draw()
    frame = np.array(fig.canvas.renderer.buffer_rgba())
    frames.append(Image.fromarray(frame))

    plt.close(fig)  # close to avoid showing each frame in notebook

frames[0].save("animation.gif", save_all=True, append_images=frames[1:], duration=100, loop=0)
from IPython.display import Image as IPyImage
IPyImage(filename="animation.gif")
# Out:
# tf.Tensor(1.0, shape=(), dtype=float64)
# tf.Tensor(1.023803328742291, shape=(), dtype=float64)
# tf.Tensor(1.091200197025725, shape=(), dtype=float64)
# tf.Tensor(1.192289483725296, shape=(), dtype=float64)
# tf.Tensor(1.3153388920507831, shape=(), dtype=float64)
# tf.Tensor(1.449469567420791, shape=(), dtype=float64)
# tf.Tensor(1.5854550673787076, shape=(), dtype=float64)
# tf.Tensor(1.7156030043159407, shape=(), dtype=float64)
# tf.Tensor(1.8334665131077976, shape=(), dtype=float64)
# tf.Tensor(1.933657539609486, shape=(), dtype=float64)
# tf.Tensor(2.0117923035939773, shape=(), dtype=float64)
# tf.Tensor(2.0645252797792093, shape=(), dtype=float64)
# tf.Tensor(2.0896200078067473, shape=(), dtype=float64)
# tf.Tensor(2.086015989460657, shape=(), dtype=float64)
# tf.Tensor(2.0538654168623993, shape=(), dtype=float64)
# tf.Tensor(1.9945277128885572, shape=(), dtype=float64)
# tf.Tensor(1.910523589759648, shape=(), dtype=float64)
# tf.Tensor(1.8054641409471195, shape=(), dtype=float64)
# tf.Tensor(1.6839848741743462, shape=(), dtype=float64)
# tf.Tensor(1.5517287992451485, shape=(), dtype=float64)
# tf.Tensor(1.4154311109994595, shape=(), dtype=float64)
# tf.Tensor(1.2831397641403286, shape=(), dtype=float64)
# tf.Tensor(1.164501936694337, shape=(), dtype=float64)
# tf.Tensor(1.0707444246461961, shape=(), dtype=float64)
# tf.Tensor(1.0134779574461945, shape=(), dtype=float64)
# tf.Tensor(1.0015090440456038, shape=(), dtype=float64)
# tf.Tensor(1.0368833261914878, shape=(), dtype=float64)
# tf.Tensor(1.113769384604302, shape=(), dtype=float64)
# tf.Tensor(1.221444033212197, shape=(), dtype=float64)
# tf.Tensor(1.3482219989035096, shape=(), dtype=float64)
# tf.Tensor(1.4836164041530895, shape=(), dtype=float64)
# tf.Tensor(1.618810493401568, shape=(), dtype=float64)
# tf.Tensor(1.7464482781080426, shape=(), dtype=float64)
# tf.Tensor(1.8603595082671531, shape=(), dtype=float64)
# tf.Tensor(1.955407925715159, shape=(), dtype=float64)
# tf.Tensor(2.0274638631709316, shape=(), dtype=float64)
# tf.Tensor(2.0734519893949623, shape=(), dtype=float64)
# tf.Tensor(2.0914244047374138, shape=(), dtype=float64)
# tf.Tensor(2.0806218894482758, shape=(), dtype=float64)
# tf.Tensor(2.041500670399433, shape=(), dtype=float64)
# tf.Tensor(1.975716148501145, shape=(), dtype=float64)
# tf.Tensor(1.8860687103091436, shape=(), dtype=float64)
# tf.Tensor(1.7764306767453892, shape=(), dtype=float64)
# tf.Tensor(1.6516879560888988, shape=(), dtype=float64)
# tf.Tensor(1.5177435911865071, shape=(), dtype=float64)
# tf.Tensor(1.3816351069134103, shape=(), dtype=float64)
# tf.Tensor(1.2517855494170371, shape=(), dtype=float64)
# tf.Tensor(1.138266042280912, shape=(), dtype=float64)
# tf.Tensor(1.0525821326963285, shape=(), dtype=float64)
# tf.Tensor(1.0060188113181516, shape=(), dtype=float64)
# tf.Tensor(1.0060188113181516, shape=(), dtype=float64)
# tf.Tensor(1.0525821326963292, shape=(), dtype=float64)
# tf.Tensor(1.1382660422809128, shape=(), dtype=float64)
# tf.Tensor(1.2517855494170371, shape=(), dtype=float64)
# tf.Tensor(1.3816351069134114, shape=(), dtype=float64)
# tf.Tensor(1.5177435911865071, shape=(), dtype=float64)
# tf.Tensor(1.6516879560888993, shape=(), dtype=float64)
# tf.Tensor(1.7764306767453892, shape=(), dtype=float64)
# tf.Tensor(1.886068710309144, shape=(), dtype=float64)
# tf.Tensor(1.975716148501145, shape=(), dtype=float64)
# tf.Tensor(2.0415006703994334, shape=(), dtype=float64)
# tf.Tensor(2.0806218894482758, shape=(), dtype=float64)
# tf.Tensor(2.091424404737414, shape=(), dtype=float64)
# tf.Tensor(2.0734519893949623, shape=(), dtype=float64)
# tf.Tensor(2.027463863170931, shape=(), dtype=float64)
# tf.Tensor(1.955407925715159, shape=(), dtype=float64)
# tf.Tensor(1.8603595082671514, shape=(), dtype=float64)
# tf.Tensor(1.746448278108041, shape=(), dtype=float64)
# tf.Tensor(1.618810493401568, shape=(), dtype=float64)
# tf.Tensor(1.4836164041530895, shape=(), dtype=float64)
# tf.Tensor(1.348221998903508, shape=(), dtype=float64)
# tf.Tensor(1.2214440332121959, shape=(), dtype=float64)
# tf.Tensor(1.1137693846043017, shape=(), dtype=float64)
# tf.Tensor(1.0368833261914878, shape=(), dtype=float64)
# tf.Tensor(1.0015090440456036, shape=(), dtype=float64)
# tf.Tensor(1.013477957446195, shape=(), dtype=float64)
# tf.Tensor(1.0707444246461961, shape=(), dtype=float64)
# tf.Tensor(1.1645019366943368, shape=(), dtype=float64)
# tf.Tensor(1.2831397641403297, shape=(), dtype=float64)
# tf.Tensor(1.4154311109994604, shape=(), dtype=float64)
# tf.Tensor(1.5517287992451485, shape=(), dtype=float64)
# tf.Tensor(1.6839848741743475, shape=(), dtype=float64)
# tf.Tensor(1.8054641409471202, shape=(), dtype=float64)
# tf.Tensor(1.910523589759648, shape=(), dtype=float64)
# tf.Tensor(1.9945277128885572, shape=(), dtype=float64)
# tf.Tensor(2.0538654168623998, shape=(), dtype=float64)
# tf.Tensor(2.086015989460657, shape=(), dtype=float64)
# tf.Tensor(2.0896200078067473, shape=(), dtype=float64)
# tf.Tensor(2.0645252797792093, shape=(), dtype=float64)
# tf.Tensor(2.011792303593977, shape=(), dtype=float64)
# tf.Tensor(1.9336575396094857, shape=(), dtype=float64)
# tf.Tensor(1.8334665131077976, shape=(), dtype=float64)
# tf.Tensor(1.7156030043159407, shape=(), dtype=float64)
# tf.Tensor(1.5854550673787065, shape=(), dtype=float64)
# tf.Tensor(1.44946956742079, shape=(), dtype=float64)
# tf.Tensor(1.3153388920507831, shape=(), dtype=float64)
# tf.Tensor(1.1922894837252946, shape=(), dtype=float64)
# tf.Tensor(1.0912001970257241, shape=(), dtype=float64)
# tf.Tensor(1.023803328742291, shape=(), dtype=float64)
# tf.Tensor(1.0, shape=(), dtype=float64)

# %%
k = 32
w = np.zeros((k,k,1,1))


t1 = np.zeros((k,k))
t2 = np.zeros((k,k))
t3 = np.zeros((k,k))
t4 = np.zeros((k,k))
t5 = np.zeros((k,k))

'''t1[1, 2] = 1.
t2[2, 1] = 1.'''
t1[0,4] = 1.
t2[1, 3] = 1.
t3[2, 2] = 1.
t4[3, 1] = 1.
t5[4, 0] = 1.


w1 = fft.idctn(t1, norm='ortho') -  fft.idctn(t5, norm='ortho')

#w1 /= np.sum(np.abs(w1))

w2 = fft.idctn(t2, norm='ortho') 





#w2 /= np.sum(np.abs(w2))

frames = []
angles = np.linspace(-np.pi, np.pi, 100)

angle0 = np.pi/8


for angle in angles :    
    
    fig, ax = plt.subplots()


    w[:,:,0,0] = np.cos(4*angle) * w1 - np.sin(4*angle)*w2




    print(tf.math.reduce_euclidean_norm(w))
    w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))


    im = ax.imshow(w[:,:,0,0], cmap=cm.viridis, animated=True)
    ax.axis("off")

    fig.canvas.draw()
    frame = np.array(fig.canvas.renderer.buffer_rgba())
    frames.append(Image.fromarray(frame))

    plt.close(fig)  # close to avoid showing each frame in notebook

frames[0].save("animation.gif", save_all=True, append_images=frames[1:], duration=100, loop=0)
from IPython.display import Image as IPyImage
IPyImage(filename="animation.gif")
# Out:
# tf.Tensor(1.4142135623730951, shape=(), dtype=float64)
# tf.Tensor(1.3917344173853328, shape=(), dtype=float64)
# tf.Tensor(1.328010818406707, shape=(), dtype=float64)
# tf.Tensor(1.2344192796257962, shape=(), dtype=float64)
# tf.Tensor(1.1304718898305754, shape=(), dtype=float64)
# tf.Tensor(1.0431498978023643, shape=(), dtype=float64)
# tf.Tensor(1.0011313793471153, shape=(), dtype=float64)
# tf.Tensor(1.020757449781272, shape=(), dtype=float64)
# tf.Tensor(1.0941641359646033, shape=(), dtype=float64)
# tf.Tensor(1.19534203509429, shape=(), dtype=float64)
# tf.Tensor(1.2955474174247485, shape=(), dtype=float64)
# tf.Tensor(1.372232568320505, shape=(), dtype=float64)
# tf.Tensor(1.4110153608771783, shape=(), dtype=float64)
# tf.Tensor(1.405359583476938, shape=(), dtype=float64)
# tf.Tensor(1.3561912497057949, shape=(), dtype=float64)
# tf.Tensor(1.2719589096172539, shape=(), dtype=float64)
# tf.Tensor(1.1690864352796944, shape=(), dtype=float64)
# tf.Tensor(1.0720366393677219, shape=(), dtype=float64)
# tf.Tensor(1.0100759937711377, shape=(), dtype=float64)
# tf.Tensor(1.0061238027982922, shape=(), dtype=float64)
# tf.Tensor(1.0617757650097892, shape=(), dtype=float64)
# tf.Tensor(1.1560562349389798, shape=(), dtype=float64)
# tf.Tensor(1.2596920611139317, shape=(), dtype=float64)
# tf.Tensor(1.3473219116240414, shape=(), dtype=float64)
# tf.Tensor(1.4014934771550087, shape=(), dtype=float64)
# tf.Tensor(1.4127906449348386, shape=(), dtype=float64)
# tf.Tensor(1.37936040568284, shape=(), dtype=float64)
# tf.Tensor(1.306792832280979, shape=(), dtype=float64)
# tf.Tensor(1.208459772425878, shape=(), dtype=float64)
# tf.Tensor(1.1059113744179252, shape=(), dtype=float64)
# tf.Tensor(1.0274153374719195, shape=(), dtype=float64)
# tf.Tensor(1.0001258564842765, shape=(), dtype=float64)
# tf.Tensor(1.03489530551767, shape=(), dtype=float64)
# tf.Tensor(1.1180339887498953, shape=(), dtype=float64)
# tf.Tensor(1.2215019517309813, shape=(), dtype=float64)
# tf.Tensor(1.31762496082396, shape=(), dtype=float64)
# tf.Tensor(1.3858667924499781, shape=(), dtype=float64)
# tf.Tensor(1.413857608897, shape=(), dtype=float64)
# tf.Tensor(1.3969478405235145, shape=(), dtype=float64)
# tf.Tensor(1.337919450036361, shape=(), dtype=float64)
# tf.Tensor(1.2471644237832098, shape=(), dtype=float64)
# tf.Tensor(1.1431655335748339, shape=(), dtype=float64)
# tf.Tensor(1.0521280590444333, shape=(), dtype=float64)
# tf.Tensor(1.0031353625816422, shape=(), dtype=float64)
# tf.Tensor(1.0149648711197083, shape=(), dtype=float64)
# tf.Tensor(1.0828525444525483, shape=(), dtype=float64)
# tf.Tensor(1.1821999263946028, shape=(), dtype=float64)
# tf.Tensor(1.2839237468261648, shape=(), dtype=float64)
# tf.Tensor(1.364502480412746, shape=(), dtype=float64)
# tf.Tensor(1.4085362440129747, shape=(), dtype=float64)
# tf.Tensor(1.4085362440129745, shape=(), dtype=float64)
# tf.Tensor(1.3645024804127455, shape=(), dtype=float64)
# tf.Tensor(1.2839237468261642, shape=(), dtype=float64)
# tf.Tensor(1.1821999263946028, shape=(), dtype=float64)
# tf.Tensor(1.0828525444525476, shape=(), dtype=float64)
# tf.Tensor(1.0149648711197083, shape=(), dtype=float64)
# tf.Tensor(1.0031353625816424, shape=(), dtype=float64)
# tf.Tensor(1.0521280590444333, shape=(), dtype=float64)
# tf.Tensor(1.1431655335748347, shape=(), dtype=float64)
# tf.Tensor(1.2471644237832098, shape=(), dtype=float64)
# tf.Tensor(1.3379194500363614, shape=(), dtype=float64)
# tf.Tensor(1.3969478405235145, shape=(), dtype=float64)
# tf.Tensor(1.413857608897, shape=(), dtype=float64)
# tf.Tensor(1.3858667924499781, shape=(), dtype=float64)
# tf.Tensor(1.3176249608239594, shape=(), dtype=float64)
# tf.Tensor(1.2215019517309813, shape=(), dtype=float64)
# tf.Tensor(1.118033988749894, shape=(), dtype=float64)
# tf.Tensor(1.0348953055176695, shape=(), dtype=float64)
# tf.Tensor(1.0001258564842765, shape=(), dtype=float64)
# tf.Tensor(1.0274153374719195, shape=(), dtype=float64)
# tf.Tensor(1.1059113744179263, shape=(), dtype=float64)
# tf.Tensor(1.208459772425879, shape=(), dtype=float64)
# tf.Tensor(1.306792832280979, shape=(), dtype=float64)
# tf.Tensor(1.37936040568284, shape=(), dtype=float64)
# tf.Tensor(1.4127906449348389, shape=(), dtype=float64)
# tf.Tensor(1.4014934771550085, shape=(), dtype=float64)
# tf.Tensor(1.3473219116240414, shape=(), dtype=float64)
# tf.Tensor(1.2596920611139322, shape=(), dtype=float64)
# tf.Tensor(1.1560562349389791, shape=(), dtype=float64)
# tf.Tensor(1.061775765009789, shape=(), dtype=float64)
# tf.Tensor(1.0061238027982922, shape=(), dtype=float64)
# tf.Tensor(1.010075993771138, shape=(), dtype=float64)
# tf.Tensor(1.0720366393677225, shape=(), dtype=float64)
# tf.Tensor(1.1690864352796944, shape=(), dtype=float64)
# tf.Tensor(1.2719589096172539, shape=(), dtype=float64)
# tf.Tensor(1.3561912497057957, shape=(), dtype=float64)
# tf.Tensor(1.4053595834769381, shape=(), dtype=float64)
# tf.Tensor(1.4110153608771783, shape=(), dtype=float64)
# tf.Tensor(1.372232568320505, shape=(), dtype=float64)
# tf.Tensor(1.295547417424748, shape=(), dtype=float64)
# tf.Tensor(1.1953420350942892, shape=(), dtype=float64)
# tf.Tensor(1.0941641359646033, shape=(), dtype=float64)
# tf.Tensor(1.020757449781272, shape=(), dtype=float64)
# tf.Tensor(1.0011313793471153, shape=(), dtype=float64)
# tf.Tensor(1.0431498978023648, shape=(), dtype=float64)
# tf.Tensor(1.1304718898305754, shape=(), dtype=float64)
# tf.Tensor(1.2344192796257978, shape=(), dtype=float64)
# tf.Tensor(1.3280108184067072, shape=(), dtype=float64)
# tf.Tensor(1.391734417385333, shape=(), dtype=float64)
# tf.Tensor(1.4142135623730951, shape=(), dtype=float64)

# %%
fig, ax= plt.subplots(1,1, figsize=(3,3))

ax.plot(angles,response_mag)

ticks = np.arange(-np.pi, 1.5*np.pi, np.pi/2)
labels = [r"$-\pi$", r"$-\pi/2$", r"$0$", r"$\pi/2$", r"$\pi$"]
# Set ticks and labels on the x-axis
ax.set_xticks(ticks=ticks, labels=labels);
ax.set_yticks(ticks=np.arange(0,1.1, 0.1));

ax.set_ylabel(r"Percent of Energy Transmitted $\left( \frac{||I_{2}||}{||I_{1}||} \right)$", fontsize=7)
ax.set_xlabel(r"Difference in kernel orrientation $(\theta_2 - \theta_1)$", fontsize=7)

plt.savefig('malus2_saddle.pdf', dpi=600)
plt.show()

# %%
i0 = tf.cast(tf.repeat(tf.expand_dims([img], axis=-1) , repeats = w.shape[-2], axis=-1), dtype=tf.float32) 

fig, ax= plt.subplots(1,1)


im =ax.imshow(i0[0,...,0])
#ax.plot(45//2, 45, marker = '+', color='red');



ax.set(xlim=(0, img.shape[0]), ylim=(0,  img.shape[1]));

x_min, x_max = 30, 60
y_min, y_max = 30, 60

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

fig.colorbar(im, orientation='vertical');

plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.savefig("i0_high_order.pdf",bbox_inches='tight',   pad_inches = 0, dpi=600)

# %%
angle = -np.pi

w = np.zeros((3,3,1,1))

w[:,:,0,0] = (np.cos(2*angle))*w1 + ( np.sin(2*angle))*w2
w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))


i0 = tf.cast(tf.repeat(tf.expand_dims([img], axis=-1) , repeats = w.shape[-2], axis=-1), dtype=tf.float32) 

print((tf.math.reduce_euclidean_norm(i0)))

i1_x = tf.nn.relu( tf.nn.conv2d(i0, w , strides=(1,1), 
							 padding='SAME') )


fig, ax= plt.subplots(1,1)

im =ax.imshow(i1[0,...,0])
#ax.plot(45//2, 45, marker = '+', color='red');




ax.set(xlim=(0, img.shape[0]), ylim=(0,  img.shape[1]));
x_min, x_max = 30, 60
y_min, y_max = 30, 60

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

fig.colorbar(im, orientation='vertical');

plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.savefig("i1_high_order.pdf",bbox_inches='tight',   pad_inches = 0, dpi=600)
tf.math.reduce_euclidean_norm(i1)
# Out:
# tf.Tensor(500.105, shape=(), dtype=float32)
# <tf.Tensor: shape=(), dtype=float32, numpy=353.0082092285156>

# %%
angle = -np.pi

w[:,:,0,0] = (np.cos(2*angle))*w1 + ( np.sin(2*angle))*w2
w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))




i2_x = tf.nn.relu( tf.nn.conv2d(i1, w , strides=(1,1), 
							 padding='SAME') )


fig, ax= plt.subplots(1,1)

im =ax.imshow(i2_x[0,...,0])
#ax.plot(45//2, 45, marker = '+', color='red');



ax.set(xlim=(0, img.shape[0]), ylim=(0,  img.shape[1]));
x_min, x_max = 30, 60
y_min, y_max = 30, 60

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)


fig.colorbar(im, orientation='vertical');

plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.savefig("i2_y_high_order.pdf",bbox_inches='tight',   pad_inches = 0, dpi=600)
tf.math.reduce_euclidean_norm(i2_x)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=277.6308288574219>

# %%
angle = np.pi/2

w[:,:,0,0] = (np.cos(2*angle))*w1 + ( np.sin(2*angle))*w2
w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))




i2_y = tf.nn.relu( tf.nn.conv2d(i1, w , strides=(1,1), 
							 padding='SAME') )


fig, ax= plt.subplots(1,1)

im =ax.imshow(i2_y[0,...,0])
#ax.plot(45//2, 45, marker = '+', color='red');



ax.set(xlim=(0, img.shape[0]), ylim=(0,  img.shape[1]));
x_min, x_max = 30, 60
y_min, y_max = 30, 60

ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)


fig.colorbar(im, orientation='vertical');

plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
plt.margins(0,0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
#plt.savefig("i2_y_high_order.pdf",bbox_inches='tight',   pad_inches = 0, dpi=600)
tf.math.reduce_euclidean_norm(i2_y)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=277.5757751464844>

# %%
i0.shape
# Out:
# TensorShape([1, 520, 520, 1])

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 7))
title_fontsize = 16  # Adjust as needed

# Top-left
im0 = axs[0, 0].imshow(i0[0,...,0].numpy(), cmap='viridis')
axs[0, 0].set_title(r'Input ($I_0 \sim N(0, 1)$)', fontsize=title_fontsize)
fig.colorbar(im0, ax=axs[0, 0], fraction=0.046, pad=0.04)
#ax.set(xlim=(0, img.shape[0]), ylim=(0,  img.shape[1]));



#fig.colorbar(im, orientation='vertical');


# Top-right
im1 = axs[0, 1].imshow(i1_x[0,...,0].numpy(), cmap='viridis')
axs[0, 1].set_title(r'$I_1 = \mathrm{ReLU}(I_0 * \nabla_y)$', fontsize=title_fontsize)
fig.colorbar(im1, ax=axs[0, 1], fraction=0.046, pad=0.04)

# Bottom-left
im2 = axs[1, 0].imshow(i2_x[0,...,0].numpy(), cmap='viridis')
axs[1, 0].set_title(r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_y)$', fontsize=title_fontsize)
fig.colorbar(im2, ax=axs[1, 0], fraction=0.046, pad=0.04)

vmin = i2_x[0,...,0].numpy().min()
vmax = i2_x[0,...,0].numpy().max()


# Bottom-right
im3 = axs[1, 1].imshow(
    i2_y[0,...,0].numpy(), 
    cmap='viridis', 
    vmin=vmin, 
    vmax=vmax
)
axs[1, 1].set_title(r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_x)$', fontsize=title_fontsize)
fig.colorbar(im2, ax=axs[1, 1], fraction=0.046, pad=0.04)

# Optional: tighten layout and remove axis ticks
for ax in axs.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.savefig("malus_saddle_circle.pdf", dpi=600)

plt.show()

# %%
np.max(i1_x), np.max(i2_x)
# Out:
# (np.float32(4.418213), np.float32(3.6113281))

# %%
np.sum(w)
# Out:
# np.float64(0.0)

# %%
np.max(tf.nn.conv2d(i0, w , strides=(1,1), padding='SAME'))
# Out:
# np.float32(5.1289062)

# %%
np.max(tf.nn.conv2d(i1, w , strides=(1,1), padding='SAME'))
# Out:
# np.float32(3.538086)

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox, TextArea, VPacker
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

def render_patch_with_border(patch, border_color='black', border_width=1, zoom=1.0):
	"""
	Renders a patch using imshow-style with a border and returns it as an OffsetImage.
	"""
	# Create a tiny figure to render the patch using imshow
	fig, ax = plt.subplots(figsize=(1, 1), dpi=100)
	canvas = FigureCanvas(fig)

	ax.imshow(patch, cmap='gray', interpolation='none')
	ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)


	for spine in ax.spines.values():
		spine.set_visible(True)
		spine.set_linewidth(1)
		spine.set_color('black')

	# Make sure spines are drawn on top of the image
	ax.set_frame_on(True)
	# Add rectangle border
	'''h, w = patch.shape
	ax.add_patch(plt.Rectangle(
		(-0.5, -0.5), w, h,
		edgecolor=border_color,
		facecolor='none',
		linewidth=border_width
	))'''

	# Render to array
	canvas.draw()
	img = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
	img = img.reshape(canvas.get_width_height()[::-1] + (3,))

	plt.close(fig)
	return OffsetImage(img, zoom=zoom)

# Function to place image on the curve

def add_patch_with_label(ax, x, y, patch, label):
	# Create rendered image with border
	imagebox = render_patch_with_border(patch, border_color='black', border_width=2, zoom=0.2)

	# Create label
	textbox = TextArea(label, textprops={
		'fontsize': 7,
		'ha': 'center',
		'va': 'center',
		'bbox': dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.1')
	})

	# Stack vertically
	vpack = VPacker(children=[textbox, imagebox], align="center", pad=0, sep=3)
	ab = AnnotationBbox(vpack, (x, y), frameon=False, box_alignment=(0.5, 0.5))

	ax.add_artist(ab)


fig, ax= plt.subplots(1,1, figsize=(3,3))

ax.plot(angles,response_mag)

ticks = np.arange(-np.pi, 1.5*np.pi, np.pi/2)
labels = [r"$-\pi$", r"$-\pi/2$", r"$0$", r"$\pi/2$", r"$\pi$"]
# Set ticks and labels on the x-axis
ax.set_xticks(ticks=ticks, labels=labels);
ax.set_yticks(ticks=np.arange(0,1.1, 0.1));

ax.set_ylabel(r"Percent of Energy Transmitted $\left( \frac{||I_{2}||}{||I_{1}||} \right)$", fontsize=10)
ax.set_xlabel(r"Difference in kernel orrientation $(\theta_2 - \theta_1)$", fontsize=10)

# Locations along curve
x1, y1 = -np.pi/2, response_mag[len(response_mag)//4]  # for dy
x2, y2 = np.pi, response_mag[-1]     # for dx
w[:,:,0,0] = (np.cos(np.pi))*w1 + ( np.sin(np.pi))*w2
dx_kernel = w[:,:,0,0]
dy_kernel = dx_kernel.T



add_patch_with_label(ax, x1,  y1-0.09, dy_kernel, r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_x\nabla_y^2)$')
add_patch_with_label(ax, x2+0.05, y2+0.1, dx_kernel, r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_y\nabla_x^2)$')


plt.savefig('malus_curve_circle_high_order.pdf', dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 83
#      78 dx_kernel = w[:,:,0,0]
#      79 dy_kernel = dx_kernel.T
# ---> 83 add_patch_with_label(ax, x1,  y1-0.09, dy_kernel, r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_x\nabla_y^2)$')
#      84 add_patch_with_label(ax, x2+0.05, y2+0.1, dx_kernel, r'$I_2 = \mathrm{ReLU}(I_1 * \nabla_y\nabla_x^2)$')
#      87 plt.savefig('malus_curve_circle_high_order.pdf', dpi=600)
#
# Cell In[18], line 44, in add_patch_with_label(ax, x, y, patch, label)
#      42 def add_patch_with_label(ax, x, y, patch, label):
#      43 	# Create rendered image with border
# ---> 44 	imagebox = render_patch_with_border(patch, border_color='black', border_width=2, zoom=0.2)
#      46 	# Create label
#      47 	textbox = TextArea(label, textprops={
#      48 		'fontsize': 7,
#      49 		'ha': 'center',
#      50 		'va': 'center',
#      51 		'bbox': dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.1')
#      52 	})
#
# Cell In[18], line 34, in render_patch_with_border(patch, border_color, border_width, zoom)
#      32 # Render to array
#      33 canvas.draw()
# ---> 34 img = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
#      35 img = img.reshape(canvas.get_width_height()[::-1] + (3,))
#      37 plt.close(fig)
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'tostring_rgb'

# %%
a = np.pi
w[:,:,0,0] = (np.cos(a))*w1 + ( np.sin(a))*w2

print((tf.math.reduce_euclidean_norm(w)))

w[:,:,0,0] = w[:,:,0,0] / (tf.math.reduce_euclidean_norm(w))
print((tf.math.reduce_euclidean_norm(w)))
# Out:
# tf.Tensor(1.0, shape=(), dtype=float64)
# tf.Tensor(1.0, shape=(), dtype=float64)

# %%
w[:,:,0,0] = (np.cos(np.pi/2))*w1 + ( np.sin(np.pi/2))*w2





p = plt.imshow(w[:,:,0,0], cmap='gray')
plt.axis('off')
p

# %%
a = np.zeros((3,3))
a[0, 1] =1
a = np.reshape(fft.idctn(a, norm='ortho'), (3,3,1,1))

b = np.zeros((3,3))
b[0, 0] =1
b = np.reshape(fft.idctn(b, norm='ortho'), (3,3,1,1))

dct_basis = a*b

plt.imshow(dct_basis[..., 0,0])
dct_basis
# Out:
# array([[[[ 0.13608276]],
#
#         [[ 0.        ]],
#
#         [[-0.13608276]]],
#
#
#        [[[ 0.13608276]],
#
#         [[ 0.        ]],
#
#         [[-0.13608276]]],
#
#
#        [[[ 0.13608276]],
#
#         [[ 0.        ]],
#
#         [[-0.13608276]]]])
